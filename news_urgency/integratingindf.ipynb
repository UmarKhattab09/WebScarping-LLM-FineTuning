# %%
import pandas as pd
df = pd.read_csv("../outputs/5.csv")

# %%
from transformers import pipeline
import numpy as np
def Urgency(News):
    zero_shot = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
    labels = ["Critical", "High", "Medium", "Low"]
    res = zero_shot(News,labels)
    loc = np.argmax(res['scores'])
    output = res['labels'][loc]
    return output
result = Urgency(df['News'][0])
print(result)
# Out:
# Device set to use cpu
# High

# %%
df['Urgency']= df['News'].apply(Urgency)
# Out:
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu

# %%
df
# Out:
#     NewsType                                               News   Urgency
# 0   politics  President Trump meets with Philippine Presiden...      High
# 1   politics  There is an ongoing staffing crunch at the Soc...  Critical
# 2   politics  The seal of the Department of Defense at the P...      High
# 3   politics  President of the National Urban League Marc Mo...  Critical
# 4   politics  Coca-Cola Chairman and CEO James Quincey says ...      High
# 5    science  Newborn babies lie in bassinets in the nursery...      High
# 6    science  Tiny variations in the weather, tides and even...      High
# 7    science  "We can really become the dominant drivers of ...  Critical
# 8    science  Did you know that the ocean produces approxima...      High
# 9    science  Many invertebrates living in the sunlight zone...  Critical
# 10    health  Sonya Sotinsky sits at Crane Cove Park in San ...    Medium
# 11    health  In Montana, one man says Medicaid and the drug...  Critical
# ...

# %%
import numpy as np
np.argmax(result['scores'])
result['labels'][0]
# highestscore = max(result['scores'])
# Out:
# 'High'
